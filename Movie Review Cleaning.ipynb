# %% [markdown]
# # Cleaning the Dataframe into a usable Dataframe

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/Admin/Documents/Movie - Data Set for Cleaning - Sheet1.csv")

# %%
df
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df.shape
# Out:
# (14, 16)

# %%
len(df)
# Out:
# 14

# %%
df.head
# Out:
# <bound method NDFrame.head of                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# ...

# %%
df.isna().any()
# Out:
# movie_title                  False
# num_critic_for_reviews       False
# duration                      True
# DIRECTOR_facebook_likes       True
# actor_3_facebook_likes       False
# ACTOR_1_facebook_likes       False
# gross                        False
# num_voted_users               True
# Cast_Total_facebook_likes     True
# facenumber_in_poster          True
# num_user_for_reviews         False
# budget                       False
# title_year                   False
# ACTOR_2_facebook_likes        True
# imdb_score                   False
# title_year.1                  True
# dtype: bool

# %%
df.dtypes
# Out:
# movie_title                   object
# num_critic_for_reviews         int64
# duration                     float64
# DIRECTOR_facebook_likes       object
# actor_3_facebook_likes         int64
# ACTOR_1_facebook_likes         int64
# gross                          int64
# num_voted_users              float64
# Cast_Total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews           int64
# budget                         int64
# title_year                     int64
# ACTOR_2_facebook_likes       float64
# imdb_score                   float64
# title_year.1                 float64
# dtype: object

# %%
# drop NuN values

df1=df.fillna(0)

# %%
df1
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
# Drop duplicate values

df2=df1.drop_duplicates(subset='movie_title',keep='first')

# %%
df2
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# 12                           Quantum of Solace?ÿ                     403
# ...

# %%
df3 = df2.reset_index(drop=True)

# %%
df3
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8       Harry Potter and the Half-Blood Prince?ÿ                     375
# 9           Batman v Superman: Dawn of Justice?ÿ                     673
# 10                            Superman Returns?ÿ                     434
# 11                           Quantum of Solace?ÿ                     403
# ...

# %%
df3.drop('title_year.1', inplace=True, axis=1)

# %%
df3
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8       Harry Potter and the Half-Blood Prince?ÿ                     375
# 9           Batman v Superman: Dawn of Justice?ÿ                     673
# 10                            Superman Returns?ÿ                     434
# 11                           Quantum of Solace?ÿ                     403
# ...

# %%
df3
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the caribbean: at world's end?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The dark knight rises?ÿ                     813
# 4                                  John carter?ÿ                     462
# 5                                 Spider-man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: age of ultron?ÿ                     635
# 8       Harry potter and the half-blood prince?ÿ                     375
# 9           Batman v superman: dawn of justice?ÿ                     673
# 10                            Superman returns?ÿ                     434
# 11                           Quantum of solace?ÿ                     403
# ...

# %%
df4 = df3["movie_title"].str[:-2]
df4
# Out:
# 0                                         Avatar
# 1       Pirates of the caribbean: at world's end
# 2                                        Spectre
# 3                          The dark knight rises
# 4                                    John carter
# 5                                   Spider-man 3
# 6                                        Tangled
# 7                        Avengers: age of ultron
# 8         Harry potter and the half-blood prince
# 9             Batman v superman: dawn of justice
# 10                              Superman returns
# 11                             Quantum of solace
# 12    Pirates of the caribbean: dead man's chest
# Name: movie_title, dtype: object

# %%
df3
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the caribbean: at world's end?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The dark knight rises?ÿ                     813
# 4                                  John carter?ÿ                     462
# 5                                 Spider-man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: age of ultron?ÿ                     635
# 8       Harry potter and the half-blood prince?ÿ                     375
# 9           Batman v superman: dawn of justice?ÿ                     673
# 10                            Superman returns?ÿ                     434
# 11                           Quantum of solace?ÿ                     403
# ...

# %%
df3
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the caribbean: at world's end?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The dark knight rises?ÿ                     813
# 4                                  John carter?ÿ                     462
# 5                                 Spider-man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: age of ultron?ÿ                     635
# 8       Harry potter and the half-blood prince?ÿ                     375
# 9           Batman v superman: dawn of justice?ÿ                     673
# 10                            Superman returns?ÿ                     434
# 11                           Quantum of solace?ÿ                     403
# ...

# %%
df4 = df3.rename(columns={'movie_title': 'Movie_Name','num_critic_for_reviews':'Num_Critic_For_Reviews','duration':'DURATION','DIRECTOR_facebook_likes':'DIRECTOR_Facebook_Likes','actor_3_facebook_likes':'ACTOR_3_Facebook_Likes','ACTOR_1_facebook_likes':'ACTOR_1_Facebook_Likes','gross':'GROSS','Cast_Total_facebook_likes':'Cast_Total_Facebook_Likes','num_voted_users':'NUM_Voted_User','facenumber_in_poster':'Face_Number_In_Poster','num_user_for_reviews':'Num_User_For_Review','budget':'BUDGET','title_year':'TITLE_YEAR','ACTOR_2_facebook_likes':'ACTOR_2_Facebook_Likes','imdb_score':'IMDB_SCORE'})

# %%
df4
# Out:
#                                       Movie_Name  Num_Critic_For_Reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the caribbean: at world's end?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The dark knight rises?ÿ                     813
# 4                                  John carter?ÿ                     462
# 5                                 Spider-man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: age of ultron?ÿ                     635
# 8       Harry potter and the half-blood prince?ÿ                     375
# 9           Batman v superman: dawn of justice?ÿ                     673
# 10                            Superman returns?ÿ                     434
# 11                           Quantum of solace?ÿ                     403
# ...

# %%
df4.head
# Out:
# <bound method NDFrame.head of                                       Movie_Name  Num_Critic_For_Reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the caribbean: at world's end?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The dark knight rises?ÿ                     813
# 4                                  John carter?ÿ                     462
# 5                                 Spider-man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: age of ultron?ÿ                     635
# 8       Harry potter and the half-blood prince?ÿ                     375
# 9           Batman v superman: dawn of justice?ÿ                     673
# 10                            Superman returns?ÿ                     434
# ...

# %%
len(df4)
# Out:
# 13

# %%
df4.shape
# Out:
# (13, 15)
